# %%
import pandas as pd
import numpy as np
people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}

# %%
# create DataFrame object
# keys are columns 
# lists of something are rows
df = pd.DataFrame(people)
df
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df.columns
# Out:
# Index(['first', 'last', 'email', 'age'], dtype='object')

# %%
df[['first', 'last']] # returns pandas.core.frame.DataFrame
# Out:
#    first     last
# 0  Corey  Schafer
# 1   Jane      Doe
# 2   John      Doe
# 3  Chris  Schafer
# 4    NaN      NaN
# 5   None      NaN
# 6     NA  Missing

# %%
df.iloc[0] # access the single row

df.iloc[[0, 1]] # access multiple rows
 
df.iloc[[0, 1], [2, 1]] # first param - rows
                        # second param  - cols
# Out:
#                      email     last
# 0  CoreyMSchafer@gmail.com  Schafer
# 1        JaneDoe@email.com      Doe

# %%
df.loc[[0, 1], ['email', 'last']] # same as iloc but takes string args for second param
# Out:
#                      email     last
# 0  CoreyMSchafer@gmail.com  Schafer
# 1        JaneDoe@email.com      Doe

# %%
# PART 4 indexes and conditionals

# set index column 
df.set_index('email') # change once
df.set_index('email', inplace=True) # change forever
df.index # nice unique identifier for the row
# Out:
# Index(['CoreyMSchafer@gmail.com',       'JaneDoe@email.com',
#              'JohnDoe@email.com',                      None,
#                              nan,     'Anonymous@email.com',
#                             'NA'],
#       dtype='object', name='email')

# %%
df.loc['CoreyMSchafer@gmail.com'] # we replaced default indexes with strings
                                  # and now the 1st arg is a string cant do df.loc[0]
# Out:
# first      Corey
# last     Schafer
# age           33
# Name: CoreyMSchafer@gmail.com, dtype: object

# %%
df.reset_index(inplace=True) # reset index assignment

# %%
filt = (df['last'] == 'Doe') & (df['first'] == 'John')
df[filt]
# Out:
#                email first last age
# 2  JohnDoe@email.com  John  Doe  63

# %%
df.loc[filt, 'email'] # 1st rows that we want, 2nd columns that we want
# Out:
# 2    JohnDoe@email.com
# Name: email, dtype: object

# %%
# PART 5 Updating rows and columns - modifying data withing the data frame

# replace columns in order
# df.columns = ['first_name', 'last_name', 'email']

# %%
# use list comprehensions
df.columns = [x.lower() for x in df.columns]
df
# Out:
#                      email  first     last      age
# 0  CoreyMSchafer@gmail.com  Corey  Schafer       33
# 1        JaneDoe@email.com   Jane      Doe       55
# 2        JohnDoe@email.com   John      Doe       63
# 3                     None  Chris  Schafer       36
# 4                      NaN    NaN      NaN     None
# 5      Anonymous@email.com   None      NaN     None
# 6                       NA     NA  Missing  Missing

# %%
# replace something in columns
df.columns = df.columns.str.replace('_', ' ') # replace all underscores with spaces vice versa
df.columns = df.columns.str.replace(' ', '_')

# %%
# rename columns 
df.rename(columns={'first_name' : 'first', 'last_name' : 'last'}, inplace=True)
df
# Out:
#                      email  first     last      age
# 0  CoreyMSchafer@gmail.com  Corey  Schafer       33
# 1        JaneDoe@email.com   Jane      Doe       55
# 2        JohnDoe@email.com   John      Doe       63
# 3                     None  Chris  Schafer       36
# 4                      NaN    NaN      NaN     None
# 5      Anonymous@email.com   None      NaN     None
# 6                       NA     NA  Missing  Missing

# %%
df.loc[2] = ['John', 'Smith', 'John@email.com']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [71], line 1
# ----> 1 df.loc[2] = ['John', 'Smith', 'John@email.com']
#
# File c:\Users\mosek\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:819, in _LocationIndexer.__setitem__(self, key, value)
#     816 self._has_valid_setitem_indexer(key)
#     818 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 819 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File c:\Users\mosek\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1798, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1796     self._setitem_with_indexer_split_path(indexer, value, name)
#    1797 else:
# -> 1798     self._setitem_single_block(indexer, value, name)
#
# File c:\Users\mosek\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:2079, in _iLocIndexer._setitem_single_block(self, indexer, value, name)
#    2076 self.obj._check_is_chained_assignment_possible()
#    2078 # actually do the set
# -> 2079 self.obj._mgr = self.obj._mgr.setitem(indexer=indexer, value=value)
#    2080 self.obj._maybe_update_cacher(clear=True, inplace=True)
#
# File c:\Users\mosek\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:389, in BaseBlockManager.setitem(self, indexer, value)
#     384 if _using_copy_on_write() and not self._has_no_reference(0):
#     385     # if being referenced -> perform Copy-on-Write and clear the reference
#     386     # this method is only called if there is a single block -> hardcoded 0
#     387     self = self.copy()
# --> 389 return self.apply("setitem", indexer=indexer, value=value)
#
# File c:\Users\mosek\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:348, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     346         applied = b.apply(f, **kwargs)
#     347     else:
# --> 348         applied = getattr(b, f)(**kwargs)
#     349 except (TypeError, NotImplementedError):
#     350     if not ignore_failures:
#
# File c:\Users\mosek\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\blocks.py:985, in Block.setitem(self, indexer, value)
#     981         if lib.is_list_like(vi):
#     982             # checking lib.is_scalar here fails on
#     983             #  test_iloc_setitem_custom_object
#     984             casted = setitem_datetimelike_compat(values, len(vi), casted)
# --> 985     values[indexer] = casted
#     986 return self
#
# ValueError: could not broadcast input array from shape (3,) into shape (4,)

# %%
# change only particular values if we do not want to modify all of them 
df.loc[2, ['last', 'email']] = ['Doe', 'JohnDoe@email.com'] # we can change as list or string for the 2nd param
df
# Out:
#                      first   last              email
# 0  CoreyMSchafer@gmail.com  Corey            Schafer
# 1        JaneDoe@email.com   Jane                Doe
# 2                     John    Doe  JohnDoe@email.com
# 3             Adam@kek.com   Adam          Adamovich

# %%
# we can not assign it like this because the copy is returned
# filt = (df['email'] == 'JohnDoe@email.com')
# df[filt]['last'] = 'Smith'

# instead we should use loc or iloc 
filt = (df['email'] == 'JohnDoe@email.com')
df.loc[filt, 'last'] = 'Smith'
df
# Out:
#                      first   last              email
# 0  CoreyMSchafer@gmail.com  Corey            Schafer
# 1        JaneDoe@email.com   Jane                Doe
# 2                     John  Smith  JohnDoe@email.com
# 3             Adam@kek.com   Adam          Adamovich

# %%
df['email'] = df['email'].str.lower()
df
# Out:
#                      first   last              email
# 0  CoreyMSchafer@gmail.com  Corey            schafer
# 1        JaneDoe@email.com   Jane                doe
# 2                     John  Smith  johndoe@email.com
# 3             Adam@kek.com   Adam          adamovich

# %%
df['email'].apply(len)
# Out:
# 0     7
# 1     3
# 2    17
# 3     9
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

df['email'].apply(str.lower)
df['email'].apply(str.upper)

# or pass custom functions ... 
# to actually modify values, we can just assign them
df['email'] = df['email'].apply(update_email)
df
# Out:
#                      first   last              email
# 0  CoreyMSchafer@gmail.com  Corey            SCHAFER
# 1        JaneDoe@email.com   Jane                DOE
# 2                     John  Smith  JOHNDOE@EMAIL.COM
# 3             Adam@kek.com   Adam          ADAMOVICH

# %%
df['email'] = df['email'].apply(lambda x: x.lower())
df
# Out:
#                      first   last              email
# 0  CoreyMSchafer@gmail.com  Corey            schafer
# 1        JaneDoe@email.com   Jane                doe
# 2                     John  Smith  johndoe@email.com
# 3             Adam@kek.com   Adam          adamovich

# %%
df.applymap(len)
# df.applymap(str.lower)
# Out:
#    first  last  email
# 0     23     5      7
# 1     17     4      3
# 2      4     5     17
# 3     12     4      9

# %%
df = pd.DataFrame(people)
df['first'].map({'Corey' : 'Chris', 'Ja ne' : 'Mary'})
# Out:
# 0    Chris
# 1      NaN
# 2      NaN
# 3      NaN
# Name: first, dtype: object

# %%
df['first'].replace({'Corey' : 'Chris', 'Ja ne' : 'Mary'}, )
# Out:
# 0    Chris
# 1     Jane
# 2     John
# 3     Adam
# Name: first, dtype: object

# %%
# Part 6 Add/remove columns

# adding new columns
df['full_name'] = df['first']  + ' ' + df['last'] 
df
# Out:
#    first       last                    email       full_name
# 0  Corey    Schafer  CoreyMSchafer@gmail.com   Corey Schafer
# 1   Jane        Doe        JaneDoe@email.com        Jane Doe
# 2   John        Doe        JohnDoe@email.com        John Doe
# 3   Adam  Adamovich             Adam@kek.com  Adam Adamovich

# %%
# remove columns
df.drop(columns=['first', 'last'])
df
# Out:
#    first       last                    email       full_name
# 0  Corey    Schafer  CoreyMSchafer@gmail.com   Corey Schafer
# 1   Jane        Doe        JaneDoe@email.com        Jane Doe
# 2   John        Doe        JohnDoe@email.com        John Doe
# 3   Adam  Adamovich             Adam@kek.com  Adam Adamovich

# %%
df['full_name'].str.split(' ', expand=True) # expand - return dataframe instead of returned lst
# Out:
#        0          1
# 0  Corey    Schafer
# 1   Jane        Doe
# 2   John        Doe
# 3   Adam  Adamovich

# %%
# add rows and deleting rows
df.append({'first' : 'Tony'}, ignore_index=True)
# Out:
# C:\Users\mosek\AppData\Local\Temp\ipykernel_15424\3738067416.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append({'first' : 'Tony'}, ignore_index=True)
#    first       last                    email       full_name
# 0  Corey    Schafer  CoreyMSchafer@gmail.com   Corey Schafer
# 1   Jane        Doe        JaneDoe@email.com        Jane Doe
# 2   John        Doe        JohnDoe@email.com        John Doe
# 3   Adam  Adamovich             Adam@kek.com  Adam Adamovich
# 4   Tony        NaN                      NaN             NaN

# %%
people = {
    "first": ["Tony", 'Steve'], 
    "last": ["Stark", 'Rogers'], 
    "email": ["IronMan@avenge.com", 'Cap@avenge.com']
}
df2 = pd.DataFrame(people)
df2
# Out:
#    first    last               email
# 0   Tony   Stark  IronMan@avenge.com
# 1  Steve  Rogers      Cap@avenge.com

# %%
# append another table to the current data frame

# df.append(df2, ignore_index=True, sort=False)

# make changes permanent
df = df.append(df2, ignore_index=True, sort=False) 
df
# Out:
# C:\Users\mosek\AppData\Local\Temp\ipykernel_15424\1347280340.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2, ignore_index=True, sort=False)
#    first       last                    email       full_name
# 0  Corey    Schafer  CoreyMSchafer@gmail.com   Corey Schafer
# 1   Jane        Doe        JaneDoe@email.com        Jane Doe
# 2   John        Doe        JohnDoe@email.com        John Doe
# 3   Adam  Adamovich             Adam@kek.com  Adam Adamovich
# 4   Tony      Stark       IronMan@avenge.com             NaN
# 5  Steve     Rogers           Cap@avenge.com             NaN

# %%
df.drop_duplicates(inplace=True) # remove all duplicates
df
# Out:
#    first       last                    email       full_name
# 0  Corey    Schafer  CoreyMSchafer@gmail.com   Corey Schafer
# 1   Jane        Doe        JaneDoe@email.com        Jane Doe
# 2   John        Doe        JohnDoe@email.com        John Doe
# 3   Adam  Adamovich             Adam@kek.com  Adam Adamovich
# 4   Tony      Stark       IronMan@avenge.com             NaN
# 5  Steve     Rogers           Cap@avenge.com             NaN

# %%
# drop with conditional
filt = df['last'] == 'Doe'
df.drop(index=df[filt].index)

# update rows
df.loc[[3, 4], 'full_name'] = 'Tony Stark'
df
# Out:
#    first       last                    email      full_name
# 0  Corey    Schafer  CoreyMSchafer@gmail.com  Corey Schafer
# 1   Jane        Doe        JaneDoe@email.com       Jane Doe
# 2   John        Doe        JohnDoe@email.com       John Doe
# 3   Adam  Adamovich             Adam@kek.com     Tony Stark
# 4   Tony      Stark       IronMan@avenge.com     Tony Stark
# 5  Steve     Rogers           Cap@avenge.com            NaN

# %%
# Partd 7 Sorting Data

# sort by key
# df.sort_values(by='last') # we pass ascending=False

# %%
# pass list of bool values 
df.sort_values(by=['first', 'last'], ascending=[True, True], inplace=False)
# Out:
#    first       last                    email      full_name
# 3   Adam  Adamovich             Adam@kek.com     Tony Stark
# 0  Corey    Schafer  CoreyMSchafer@gmail.com  Corey Schafer
# 1   Jane        Doe        JaneDoe@email.com       Jane Doe
# 2   John        Doe        JohnDoe@email.com       John Doe
# 5  Steve     Rogers           Cap@avenge.com            NaN
# 4   Tony      Stark       IronMan@avenge.com     Tony Stark

# %%
# undo previous sorting
df.sort_index()
df
# Out:
#    first       last                    email      full_name
# 0  Corey    Schafer  CoreyMSchafer@gmail.com  Corey Schafer
# 1   Jane        Doe        JaneDoe@email.com       Jane Doe
# 2   John        Doe        JohnDoe@email.com       John Doe
# 3   Adam  Adamovich             Adam@kek.com     Tony Stark
# 4   Tony      Stark       IronMan@avenge.com     Tony Stark
# 5  Steve     Rogers           Cap@avenge.com            NaN

# %%
import pandas as pd
import numpy as np
people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}

# %%
# Draop all NA values
# index - drop rows with na values, columns - drop columns with na values
# any - drop any rows with na values, all - drop if all values are missing
df.dropna(axis='columns', how='all')
# Out:
#                      email  first     last      age
# 0  CoreyMSchafer@gmail.com  Corey  Schafer       33
# 1        JaneDoe@email.com   Jane      Doe       55
# 2        JohnDoe@email.com   John      Doe       63
# 3                     None  Chris  Schafer       36
# 4                      NaN    NaN      NaN     None
# 5      Anonymous@email.com   None      NaN     None
# 6                       NA     NA  Missing  Missing

# %%
# replace all na values with a string
df.fillna('MISSING')
# Out:
#                      email    first     last      age
# 0  CoreyMSchafer@gmail.com    Corey  Schafer       33
# 1        JaneDoe@email.com     Jane      Doe       55
# 2        JohnDoe@email.com     John      Doe       63
# 3                  MISSINg    Chris  Schafer       36
# 4                  MISSINg  MISSINg  MISSINg  MISSINg
# 5      Anonymous@email.com  MISSINg  MISSINg  MISSINg
# 6                       NA       NA  Missing  Missing
